# %%
def get_subfolders_list():
    return [f for f in os.listdir() if os.path.isdir(f) and not f.startswith('.')]

# !git clone --recursive https://github.com/LorenzoTausani/XDREAM_custom_LT.git
import os
from importlib.machinery import SourceFileLoader
# %cd XDREAM_custom_LT
base_dir = os.getcwd()

c=0
py_files = {}
for r, d, files in os.walk(base_dir):
  if c== 3:
    print(r)
    #break
  c=c+1
  for f in files:
    if f.endswith('.py'):
      py_files[f]=r

import sys
sys.path.append(base_dir)
from xdream import *
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Cloning into 'XDREAM_custom_LT'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 122 (delta 50), reused 101 (delta 32), pack-reused 0
# Receiving objects: 100% (122/122), 6.29 MiB | 33.56 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/XDREAM_custom_LT
# /content/XDREAM_custom_LT/xdream/net_utils
# Mounted at /content/drive

# %%
"""
Runs an experiment to maximize activity of a 'neuron,' simulated
    by a unit in a CNN.
Demonstrates a high-level API: `CNNExperiment`, which is designed to simulate an
    electrophysiology experiment and behaves similarly to `EphysExperiment`
"""

from pathlib import Path
import sys
sys.path.append('../xdream')    # or, add to path in your environment
from xdream.Experiments import CNNExperiment


# parameters
exp_settings = {
    'project_dir': 'demo',    # change as needed
    'target_neuron': ('alexnet', 'features.0', 56, 25, 25),
    # 'target_neuron': ('caffenet', 'fc8', 1),    # toggle with above to use CaffeNet
    'scorer_parameters': {'engine': 'pytorch'},    # comment out to use CaffeNet
    'optimizer_name': 'genetic',
    'optimizer_parameters': {
        'generator_parameters': {'engine': 'pytorch'},    # comment out to use caffe
        'generator_name': 'deepsim-fc6',
        'population_size': 20,
        'mutation_rate': 0.5,
        'mutation_size': 0.5,
        'selectivity': 2,
        'heritability': 0.5,
        'n_conserve': 0},
    'with_write': True,    # simulates file-writing behavior of EphysExperiment
    'image_size': 128,     # comment out to use default generator output size
    'max_optimize_images': 1000,     # query at most this many images
    'random_seed': 0,
    'config_file_path': None,    # makes a copy of this file in exp_dir, for debugging/recordkeeping
    # 'stochastic': False,    # simulates neuronal noise
    # 'wait_each_step': 0     # simulates a delay of image presentation
}


Path(exp_settings['project_dir']).mkdir(exist_ok=True)
experiment = CNNExperiment(**exp_settings)
experiment.run()
# Out:
# Genetic: random seed set to 0
# WithIOCNNScorer: not stochastic; stochastic random seed 0 not used
# BlockWriter: random seed set to 0
#
# >>> step 0
# saving scores to demo/backup/scores_end_block000.npz
# kT: 0.439238
# synthetic img scores: mean 0.5489001780748367, all [0.     2.4985 0.     0.     0.     0.0461 0.     0.4912 1.3546 0.
#  0.5631 0.     0.     0.565  0.4522 3.0144 1.7794 0.2133 0.     0.    ]
# step 0 time: total 0.93s | wait for results 0.84s  write records 0.00s  optimizer update 0.09s
#
# >>> step 1
# saving scores to demo/backup/scores_end_block001.npz
# kT: 1.075079
# synthetic img scores: mean 3.0789100259542463, all [1.8171 5.9328 5.1777 3.1725 6.165  0.6811 0.     4.6218 2.906  2.6239
#  0.     1.9714 6.8263 2.1795 6.4709 0.     2.057  2.0234 4.4572 2.4947]
# step 1 time: total 0.60s | wait for results 0.41s  write records 0.00s  optimizer update 0.19s
#
# >>> step 2
# saving scores to demo/backup/scores_end_block002.npz
# kT: 1.409737
# synthetic img scores: mean 3.759808900952339, all [3.2426 5.2771 8.5815 0.5177 0.     0.     2.8559 4.2565 4.1508 7.9203
#  7.2299 3.5824 5.5364 8.6997 3.0386 0.     3.6614 0.     1.446  5.1996]
# step 2 time: total 0.51s | wait for results 0.42s  write records 0.00s  optimizer update 0.08s
#
# >>> step 3
# saving scores to demo/backup/scores_end_block003.npz
# kT: 1.563198
# synthetic img scores: mean 6.443454599380493, all [ 9.6215  4.2344  5.6097 11.6215  1.9174  4.0851  2.5426  8.1688  5.7996
#   2.6397  8.1453  3.0592  8.0834  9.9017 10.28    6.5741  5.8436  9.9828
#   9.5619  1.1966]
# step 3 time: total 0.71s | wait for results 0.60s  write records 0.01s  optimizer update 0.10s
#
# >>> step 4
# saving scores to demo/backup/scores_end_block004.npz
# kT: 1.569608
# synthetic img scores: mean 7.283130872249603, all [ 9.1683  8.4199  9.9694  7.5821  9.114   6.8691  8.2937  3.4239 12.3346
#   6.7612  5.4345  8.3059  1.9714  2.9244  4.0617 10.9798  0.8485  7.9868
#  10.5699 10.6435]
# step 4 time: total 0.72s | wait for results 0.62s  write records 0.01s  optimizer update 0.10s
#
# >>> step 5
# saving scores to demo/backup/scores_end_block005.npz
# kT: 1.783359
# synthetic img scores: mean 7.71711220741272, all [ 7.0877 11.5459  9.1185 12.7561  9.4098  2.7967 12.1924  2.3203  3.7683
#   6.7922  6.5819  9.9967  9.8813  5.5168 10.836   8.6429  9.8359 11.4188
#   3.8442  0.    ]
# step 5 time: total 0.74s | wait for results 0.64s  write records 0.01s  optimizer update 0.10s
#
# >>> step 6
# saving scores to demo/backup/scores_end_block006.npz
# kT: 1.581145
# synthetic img scores: mean 7.751671111583709, all [ 6.8552 11.0432 10.0048  9.4878  6.4983  6.7216  9.4035  9.4198 13.2269
#   3.0065 11.4581  2.1225  8.4929 13.7539  6.7827  5.7374  5.0441  5.0876
#   7.3865  3.5001]
# step 6 time: total 0.75s | wait for results 0.64s  write records 0.01s  optimizer update 0.10s
#
# >>> step 7
# saving scores to demo/backup/scores_end_block007.npz
# kT: 1.553751
# synthetic img scores: mean 10.078235566616058, all [12.0649  6.8524  6.8142  8.7177 11.4945  7.6931 14.1948 14.1084 14.8913
#  12.0671 10.248  13.1292  9.8812  8.6041 14.5405  3.3402  8.3854  6.1816
#   8.2464 10.1097]
# step 7 time: total 0.58s | wait for results 0.49s  write records 0.00s  optimizer update 0.09s
#
# >>> step 8
# saving scores to demo/backup/scores_end_block008.npz
# kT: 1.491667
# synthetic img scores: mean 12.44455132484436, all [15.8623 14.9869 13.1479 13.5059 14.381  12.3842 14.8113 11.9376 13.7859
#  13.8164 14.8654 13.8259 14.0829  9.2964  9.3376 12.4732 11.9089  2.4735
#  13.3564  8.6514]
# step 8 time: total 0.51s | wait for results 0.42s  write records 0.00s  optimizer update 0.09s
#
# >>> step 9
# saving scores to demo/backup/scores_end_block009.npz
# kT: 1.099749
# synthetic img scores: mean 12.531095886230469, all [ 9.5963 10.6531 15.6837 14.2466 13.8713  8.9045 12.1834  8.3459 12.4194
#  12.6818 13.4377 12.542  11.5701 13.1093 10.6017 13.5654 13.4083 12.7937
#  12.884  18.1238]
# step 9 time: total 0.51s | wait for results 0.42s  write records 0.00s  optimizer update 0.08s
#
# >>> step 10
# saving scores to demo/backup/scores_end_block010.npz
# kT: 1.271685
# synthetic img scores: mean 14.018620872497559, all [14.8022 14.9346 13.3943 14.992  10.598  10.3335 18.1226 10.4246 13.0883
#  18.0481 16.1633 18.0719 14.2743  9.7241 12.1614 11.9028 16.1865 15.3318
#  13.3942 14.4241]
# step 10 time: total 0.48s | wait for results 0.39s  write records 0.00s  optimizer update 0.08s
#
# >>> step 11
# saving scores to demo/backup/scores_end_block011.npz
# kT: 1.291827
# synthetic img scores: mean 15.663049697875977, all [17.5364 18.9665 18.4781 15.4553 12.9926 11.6714 13.3816 13.9157 17.4273
#  19.0243 17.0199 14.9852 13.4735 17.5172 19.1284 19.0168 11.7406 15.4255
#  11.9299 14.1746]
# step 11 time: total 0.50s | wait for results 0.41s  write records 0.00s  optimizer update 0.09s
#
# >>> step 12
# saving scores to demo/backup/scores_end_block012.npz
# kT: 0.881001
# synthetic img scores: mean 16.91071581840515, all [18.1046 16.6597 19.621  14.4643 15.6163 17.4032 14.6304 14.6369 16.1089
#  17.6102 15.9112 18.9828 17.0011 20.6397 17.2302 13.944  15.9241 17.6924
#  17.091  18.9423]
# step 12 time: total 0.51s | wait for results 0.42s  write records 0.00s  optimizer update 0.09s
#
# >>> step 13
# saving scores to demo/backup/scores_end_block013.npz
# kT: 0.965239
# synthetic img scores: mean 18.327206945419313, all [14.9343 20.0601 18.4016 18.0008 17.2736 21.8355 18.9326 19.2303 17.95
#  19.4699 20.4239 16.5184 20.1175 17.7641 17.0519 19.809  20.565  13.8945
#  16.3056 18.0056]
# step 13 time: total 0.52s | wait for results 0.43s  write records 0.01s  optimizer update 0.09s
#
# >>> step 14
# saving scores to demo/backup/scores_end_block014.npz
# kT: 0.958474
# synthetic img scores: mean 17.909664583206176, all [19.2092 16.0607 18.1635 16.1204 18.6829 17.119  16.7549 21.6224 15.1519
#  17.2991 22.2654 19.4942 18.5647 16.1669 15.8127 19.3082 15.7206 16.522
#  19.2409 18.9138]
# step 14 time: total 0.50s | wait for results 0.41s  write records 0.00s  optimizer update 0.09s
#
# >>> step 15
# saving scores to demo/backup/scores_end_block015.npz
# kT: 1.362305
# synthetic img scores: mean 19.8849148273468, all [18.177  20.3643 23.0966 17.8189 21.1341 21.197  18.7593 21.6728 16.8569
#  10.8767 18.1085 20.3142 21.0949 22.0128 21.7908 21.654  23.8158 19.456
#  20.4237 19.074 ]
# step 15 time: total 0.51s | wait for results 0.41s  write records 0.00s  optimizer update 0.09s
#
# >>> step 16
# saving scores to demo/backup/scores_end_block016.npz
# kT: 1.582269
# synthetic img scores: mean 20.546696853637695, all [19.9119 21.798  23.0192 20.769  11.0807 22.2727 13.8048 21.8697 23.9087
#  19.2402 23.3002 23.4872 19.4266 22.0493 24.1116 21.4333 20.1662 18.1549
#  20.9228 20.2071]
# step 16 time: total 0.51s | wait for results 0.42s  write records 0.00s  optimizer update 0.08s
#
# >>> step 17
# saving scores to demo/backup/scores_end_block017.npz
# kT: 1.557132
# synthetic img scores: mean 21.015043020248413, all [21.9784 18.7193 23.4258 22.3136 20.9087 20.2038 20.5496 22.3627 22.7899
#  22.2454 21.9679 23.754  21.2048 10.5844 17.3311 23.1545 16.6124 23.5514
#  22.5935 24.0497]
# step 17 time: total 0.66s | wait for results 0.57s  write records 0.00s  optimizer update 0.09s
#
# >>> step 18
# saving scores to demo/backup/scores_end_block018.npz
# kT: 1.075608
# synthetic img scores: mean 21.07281627655029, all [19.708  22.711  22.0996 21.8285 20.5197 22.7554 16.285  21.9816 19.7464
#  23.6481 20.5004 24.128  16.7828 22.2915 21.3811 23.2672 22.3847 17.756
#  22.2213 19.4601]
# step 18 time: total 0.48s | wait for results 0.39s  write records 0.00s  optimizer update 0.09s
#
# >>> step 19
# saving scores to demo/backup/scores_end_block019.npz
# kT: 1.361004
# synthetic img scores: mean 21.045368909835815, all [14.9324 22.2897 17.2296 24.3171 24.6646 24.3709 24.3084 21.2461 17.5359
#  23.3892 20.5587 23.1833 17.8715 21.1614 21.8092 18.9399 20.0067 22.8882
#  18.4922 21.7123]
# step 19 time: total 0.50s | wait for results 0.42s  write records 0.00s  optimizer update 0.08s
#
# >>> step 20
# saving scores to demo/backup/scores_end_block020.npz
# kT: 1.612602
# synthetic img scores: mean 21.70805435180664, all [14.0376 23.2072 17.2037 24.3657 19.8334 24.9315 26.7599 23.7059 23.2736
#  22.3089 23.8112 20.6232 20.9742 18.036  16.9865 23.4613 26.5359 22.8053
#  21.5536 19.7466]
# step 20 time: total 0.49s | wait for results 0.40s  write records 0.00s  optimizer update 0.09s
#
# >>> step 21
# saving scores to demo/backup/scores_end_block021.npz
# kT: 1.446566
# synthetic img scores: mean 24.094145345687867, all [21.7744 24.9317 24.3262 25.2381 25.9069 22.0752 26.8058 25.2989 26.2455
#  20.6481 14.149  25.2451 23.6152 23.8314 22.6617 24.7643 27.4647 27.5604
#  24.3384 25.0019]
# step 21 time: total 0.50s | wait for results 0.41s  write records 0.00s  optimizer update 0.08s
#
# >>> step 22
# saving scores to demo/backup/scores_end_block022.npz
# kT: 1.258266
# synthetic img scores: mean 24.558137130737304, all [28.7579 25.4566 24.2669 22.8753 25.911  25.4169 24.0286 25.9941 20.8411
#  25.8817 27.8077 26.9802 22.9404 23.6619 26.4263 26.6124 23.9534 17.4404
#  23.6942 22.2156]
# step 22 time: total 0.48s | wait for results 0.39s  write records 0.00s  optimizer update 0.08s
#
# >>> step 23
# saving scores to demo/backup/scores_end_block023.npz
# kT: 1.179754
# synthetic img scores: mean 25.41534833908081, all [22.1616 28.8608 27.4358 26.7351 27.4798 22.7    25.4619 24.922  22.4622
#  29.3323 25.1374 20.7448 26.5619 22.5326 26.9762 22.775  27.1273 26.9729
#  26.3092 25.6182]
# step 23 time: total 0.51s | wait for results 0.42s  write records 0.01s  optimizer update 0.09s
#
# >>> step 24
# saving scores to demo/backup/scores_end_block024.npz
# kT: 1.079639
# synthetic img scores: mean 27.22238235473633, all [25.0962 28.5458 26.762  30.7559 25.673  28.333  27.1583 29.6406 27.4456
#  29.3161 29.0954 21.0398 27.8303 24.9465 27.0972 25.6693 27.0339 25.8346
#  30.1627 27.0113]
# step 24 time: total 0.49s | wait for results 0.40s  write records 0.00s  optimizer update 0.08s
#
# >>> step 25
# saving scores to demo/backup/scores_end_block025.npz
# kT: 1.340305
# synthetic img scores: mean 27.751220226287842, all [30.4332 27.9923 29.4518 22.1285 26.2979 28.6118 28.5974 27.8682 23.927
#  23.2892 29.1292 28.6137 24.0216 24.6931 29.6775 31.7095 31.3974 29.2212
#  28.7951 29.1689]
# step 25 time: total 0.52s | wait for results 0.43s  write records 0.00s  optimizer update 0.09s
#
# >>> step 26
# saving scores to demo/backup/scores_end_block026.npz
# kT: 1.815218
# synthetic img scores: mean 27.71512966156006, all [29.5247 27.6144 24.7602 28.3133 27.5672 30.6293 20.0189 30.534  25.0411
#  30.9609 32.4679 28.4949 25.6109 27.4861 29.5858 28.4006 28.828  31.4797
#  17.3634 29.6214]
# step 26 time: total 0.52s | wait for results 0.42s  write records 0.00s  optimizer update 0.10s
#
# >>> step 27
# saving scores to demo/backup/scores_end_block027.npz
# kT: 1.303608
# synthetic img scores: mean 29.309324932098388, all [23.9048 32.308  32.589  29.8746 30.8344 27.6174 30.2869 29.2358 28.2151
#  26.7613 30.4861 26.0112 27.9126 28.8276 28.9535 32.4754 30.9427 33.3334
#  24.2818 31.3348]
# step 27 time: total 0.73s | wait for results 0.63s  write records 0.01s  optimizer update 0.09s
#
# >>> step 28
# saving scores to demo/backup/scores_end_block028.npz
# kT: 1.095283
# synthetic img scores: mean 29.944151878356934, all [28.0723 34.0505 29.6947 25.4797 30.8819 32.5451 25.9376 31.9866 28.4345
#  27.6175 28.1136 30.458  30.606  30.337  30.6991 30.5011 33.0219 28.5744
#  30.0277 31.8439]
# step 28 time: total 0.74s | wait for results 0.64s  write records 0.01s  optimizer update 0.10s
#
# >>> step 29
# saving scores to demo/backup/scores_end_block029.npz
# kT: 1.365132
# synthetic img scores: mean 30.396865463256837, all [30.8877 24.685  29.607  32.2378 34.2561 28.895  25.8596 31.6714 25.4097
#  32.6222 32.5086 26.9327 30.8635 31.6016 30.4836 30.4381 32.1242 34.9588
#  31.4394 30.4553]
# step 29 time: total 0.75s | wait for results 0.63s  write records 0.01s  optimizer update 0.11s
#
# >>> step 30
# saving scores to demo/backup/scores_end_block030.npz
# kT: 2.169120
# synthetic img scores: mean 29.234971809387208, all [17.1535 33.6978 30.3878 30.5644 26.8421 29.0058 18.8121 28.4477 29.2465
#  29.148  34.7919 29.1276 30.2748 28.6471 33.0485 34.0255 32.4076 27.9687
#  32.4804 28.6217]
# step 30 time: total 0.74s | wait for results 0.63s  write records 0.01s  optimizer update 0.10s
#
# >>> step 31
# saving scores to demo/backup/scores_end_block031.npz
# kT: 1.294903
# synthetic img scores: mean 31.555710792541504, all [33.9706 33.6929 33.0053 32.231  27.865  34.7121 31.1103 26.1432 29.997
#  30.5252 31.3904 32.782  26.817  34.6356 28.3201 34.2898 35.1598 31.3936
#  31.2346 31.8388]
# step 31 time: total 0.51s | wait for results 0.41s  write records 0.00s  optimizer update 0.09s
#
# >>> step 32
# saving scores to demo/backup/scores_end_block032.npz
# kT: 0.980029
# synthetic img scores: mean 32.141776180267335, all [34.5152 29.7281 32.3432 29.6467 30.6122 34.1384 30.5143 34.3467 29.701
#  36.5233 31.3423 31.6337 31.552  31.2454 32.2009 33.3567 30.057  35.226
#  30.9092 33.2433]
# step 32 time: total 0.49s | wait for results 0.40s  write records 0.00s  optimizer update 0.08s
#
# >>> step 33
# saving scores to demo/backup/scores_end_block033.npz
# kT: 1.226557
# synthetic img scores: mean 33.39383792877197, all [36.3253 36.3037 33.1565 27.1259 34.3895 33.4961 31.2172 33.1974 34.2555
#  33.0137 32.2308 29.3385 29.672  35.5236 34.2993 36.9024 33.5267 34.0312
#  36.1171 33.7542]
# step 33 time: total 0.51s | wait for results 0.41s  write records 0.00s  optimizer update 0.09s
#
# >>> step 34
# saving scores to demo/backup/scores_end_block034.npz
# kT: 1.034888
# synthetic img scores: mean 34.57650632858277, all [36.138  33.8996 31.2761 35.2939 38.7591 34.3586 34.2574 37.2929 33.2989
#  31.1894 36.4657 34.1797 36.0389 34.3319 31.2497 33.4681 34.5658 35.6157
#  37.543  32.3076]
# step 34 time: total 0.49s | wait for results 0.39s  write records 0.00s  optimizer update 0.09s
#
# >>> step 35
# saving scores to demo/backup/scores_end_block035.npz
# kT: 1.349672
# synthetic img scores: mean 34.14979419708252, all [34.9221 33.0516 30.9268 35.032  32.9194 30.9904 32.5242 37.4738 37.0403
#  28.2343 32.6164 35.4384 33.1601 31.1326 32.7271 35.4552 36.1399 38.6881
#  36.1487 38.3746]
# step 35 time: total 0.49s | wait for results 0.40s  write records 0.01s  optimizer update 0.09s
#
# >>> step 36
# saving scores to demo/backup/scores_end_block036.npz
# kT: 1.424369
# synthetic img scores: mean 35.966323661804196, all [37.9886 35.3285 26.4164 33.1591 37.505  35.7776 37.783  36.542  35.8922
#  37.1749 36.6014 35.0372 37.1774 37.4923 36.19   37.703  37.4742 30.8462
#  38.0999 39.1375]
# step 36 time: total 0.51s | wait for results 0.42s  write records 0.00s  optimizer update 0.09s
#
# >>> step 37
# saving scores to demo/backup/scores_end_block037.npz
# kT: 1.111362
# synthetic img scores: mean 35.59542093276978, all [33.3614 35.675  37.3012 36.3909 34.3892 38.3644 35.5002 38.3232 36.5074
#  29.5211 36.4984 37.0518 37.5152 36.1388 35.0112 33.9073 36.1562 34.0915
#  38.4783 31.7259]
# step 37 time: total 0.52s | wait for results 0.42s  write records 0.01s  optimizer update 0.09s
#
# >>> step 38
# saving scores to demo/backup/scores_end_block038.npz
# kT: 1.651413
# synthetic img scores: mean 35.0164981842041, all [36.1289 37.393  33.8595 37.0018 36.8033 32.5889 27.9992 35.9283 33.7085
#  25.494  37.2521 37.1885 38.3831 37.6054 38.7478 33.3515 37.8564 34.138
#  34.9687 33.9333]
# step 38 time: total 0.49s | wait for results 0.40s  write records 0.00s  optimizer update 0.09s
#
# >>> step 39
# saving scores to demo/backup/scores_end_block039.npz
# kT: 1.181196
# synthetic img scores: mean 35.89610424041748, all [33.8464 39.0255 33.7418 33.9964 38.3464 37.2652 33.4212 34.8351 38.6828
#  37.5934 35.2335 33.529  36.087  36.9456 37.6803 31.3218 31.9814 37.1027
#  39.1106 38.1759]
# step 39 time: total 0.50s | wait for results 0.41s  write records 0.00s  optimizer update 0.09s
#
# >>> step 40
# saving scores to demo/backup/scores_end_block040.npz
# kT: 2.045629
# synthetic img scores: mean 35.46596002578735, all [32.7014 37.9524 37.7137 26.4137 33.3702 34.8363 36.4975 39.9889 39.9287
#  35.2722 30.833  36.6479 36.4459 36.0415 24.6494 37.4583 36.3607 38.7899
#  36.5083 40.9093]
# step 40 time: total 0.50s | wait for results 0.41s  write records 0.00s  optimizer update 0.09s
#
# >>> step 41
# saving scores to demo/backup/scores_end_block041.npz
# kT: 1.328714
# synthetic img scores: mean 36.54856023788452, all [40.4604 37.0396 37.2629 37.1531 37.1794 33.9393 29.0016 38.2796 36.218
#  35.5265 37.9949 36.513  37.2707 39.534  39.6627 35.6951 33.0944 40.2505
#  34.2362 34.6594]
# step 41 time: total 0.48s | wait for results 0.39s  write records 0.01s  optimizer update 0.09s
#
# >>> step 42
# saving scores to demo/backup/scores_end_block042.npz
# kT: 0.733318
# synthetic img scores: mean 37.86393871307373, all [37.5536 37.3399 35.5043 38.4518 38.0344 36.4413 34.9743 37.5857 38.5627
#  37.879  38.7678 37.6422 35.2662 39.4485 39.8163 37.5195 37.5617 39.0638
#  39.0331 40.8327]
# step 42 time: total 0.49s | wait for results 0.40s  write records 0.00s  optimizer update 0.08s
#
# >>> step 43
# saving scores to demo/backup/scores_end_block043.npz
# kT: 1.513823
# synthetic img scores: mean 37.55977363586426, all [38.3558 38.9181 27.0817 37.5306 37.6051 37.6566 38.6251 39.4091 34.498
#  33.1386 39.5406 38.2277 40.3871 35.764  38.9071 40.7559 38.9492 37.2304
#  38.356  40.2588]
# step 43 time: total 0.50s | wait for results 0.41s  write records 0.00s  optimizer update 0.08s
#
# >>> step 44
# saving scores to demo/backup/scores_end_block044.npz
# kT: 2.174517
# synthetic img scores: mean 35.35226173400879, all [37.929  34.9344 39.8018 38.83   37.2712 31.1464 37.1346 37.8534 34.8685
#  39.4969 38.2243 38.7474 25.7566 36.3032 22.5747 33.3105 33.8527 35.874
#  34.8808 38.2549]
# step 44 time: total 0.49s | wait for results 0.40s  write records 0.00s  optimizer update 0.08s
#
# >>> step 45
# saving scores to demo/backup/scores_end_block045.npz
# kT: 1.651180
# synthetic img scores: mean 36.10869255065918, all [36.1601 36.7507 31.1976 33.9627 39.2641 31.8036 36.1272 39.6899 38.6234
#  37.7926 38.5303 39.2366 28.9945 38.5607 34.3264 39.5176 39.3644 30.2732
#  34.1617 37.8364]
# step 45 time: total 0.50s | wait for results 0.41s  write records 0.00s  optimizer update 0.09s
#
# >>> step 46
# saving scores to demo/backup/scores_end_block046.npz
# kT: 1.791731
# synthetic img scores: mean 36.35868291854858, all [38.1047 40.1264 37.2781 32.2883 35.913  40.4103 35.3623 39.5651 38.304
#  36.6861 35.6906 37.165  34.2192 34.1815 39.9522 32.9151 38.7498 36.2057
#  39.5099 24.5464]
# step 46 time: total 0.51s | wait for results 0.42s  write records 0.00s  optimizer update 0.08s
#
# >>> step 47
# saving scores to demo/backup/scores_end_block047.npz
# kT: 1.114867
# synthetic img scores: mean 37.02108287811279, all [36.1734 38.7421 34.0469 34.7864 38.0258 39.1616 37.8075 34.1037 33.0762
#  40.171  35.768  39.6161 37.4949 38.8328 34.5989 35.7804 40.4376 34.7185
#  37.8676 39.2122]
# step 47 time: total 0.51s | wait for results 0.42s  write records 0.00s  optimizer update 0.08s
#
# >>> step 48
# saving scores to demo/backup/scores_end_block048.npz
# kT: 1.401256
# synthetic img scores: mean 37.665028190612794, all [33.0335 35.7727 37.8413 39.0822 38.3327 39.5746 33.3148 38.3801 40.1075
#  37.3802 42.061  36.2872 37.6835 38.5497 37.1262 39.9558 41.3903 38.3802
#  30.121  38.9262]
# step 48 time: total 0.50s | wait for results 0.42s  write records 0.00s  optimizer update 0.08s
#
# >>> step 49
# saving scores to demo/backup/scores_end_block049.npz
# kT: 1.620639
# synthetic img scores: mean 37.96058044433594, all [35.2815 32.5205 38.3438 35.1103 40.2067 40.7157 37.0673 37.0408 40.6634
#  28.0623 38.7688 36.127  37.3713 39.6442 41.268  39.8019 40.108  41.2153
#  40.6138 39.2807]
# step 49 time: total 0.50s | wait for results 0.41s  write records 0.00s  optimizer update 0.09s
#
# finished <<<
